# %%
import pandas as pd

import requests
import wget
from bs4 import BeautifulSoup
from pathlib import Path
from sqlalchemy import create_engine
import psycopg2 
import io

# %%
url = "https://www.gov.br/anvisa/pt-br/assuntos/medicamentos/cmed/precos"

r = requests.get(url, allow_redirects=True)
soup = BeautifulSoup(r.content, "html.parser")
links_with_text = []
for a in soup.find_all('a', href=True): 
    if a.text: 
        links_with_text.append(a['href'])
        
       #xls_conformidade_site_ 
        

k = [k for k in links_with_text if 'xls_conformidade_site' in k] 
file_url = k[0]

file_url = file_url.replace("/@@download/file", "")
file_name = file_url.split('/')[-1]

file_exists = Path(file_name)
if file_exists.is_file():
    #quit()
    print("OK")
    
    
print(file_name)
file_url
filename = wget.download(file_url, file_name)
filename
# Out:
# xls_conformidade_site_20240418_131155629.xls
# 100% [..................................................................] 31153664 / 31153664
# 'xls_conformidade_site_20240418_131155629.xls'

# %%
df  = pd.read_excel(filename, header=None)

df = df.iloc[41:,:]

# %%
df.columns = df.iloc[0]

# %%
df = df.iloc[1:,:]
df
# Out:
# 41                                            SUBSTÂNCIA                CNPJ  \
# 42                21-ACETATO DE DEXAMETASONA;CLOTRIMAZOL  18.459.628/0001-15
# 43                                            ABATACEPTE  56.998.982/0001-07
# 44                                            ABATACEPTE  56.998.982/0001-07
# 45                                            ABATACEPTE  56.998.982/0001-07
# 46                                            ABCIXIMABE  51.780.468/0001-87
# ...                                                  ...                 ...
# 29889  ÓXIDO DE MAGNÉSIO;SIMETICONA;HIDRÓXIDO DE ALUM...  61.190.096/0001-92
# 29890                                     ÓXIDO DE ZINCO  30.222.814/0001-31
# 29891                                     ÓXIDO DE ZINCO  30.222.814/0001-31
# 29892              ÓXIDO DE ZINCO;RETINOL;COLECALCIFEROL  73.856.593/0001-66
# 29893                     ÓXIDO DE ZINCO;ÁCIDO ASCÓRBICO  02.456.955/0001-83
#
# 41                                LABORATÓRIO     CÓDIGO GGREM       REGISTRO  \
# 42                                 BAYER S.A.  538912020009303  1705600230032
# 43     BRISTOL-MYERS SQUIBB FARMACÊUTICA LTDA  505107701157215  1018003900019
# 44     BRISTOL-MYERS SQUIBB FARMACÊUTICA LTDA  505113030019605  1018003900027
# 45     BRISTOL-MYERS SQUIBB FARMACÊUTICA LTDA  505113100020505  1018003900078
# 46            JANSSEN-CILAG FARMACÊUTICA LTDA  514517110034217  1123634150015
# ...                                       ...              ...            ...
# 29889             EUROFARMA LABORATÓRIOS S.A.  508011804138416  1004306960107
# 29890   VITAMEDIC INDUSTRIA FARMACEUTICA LTDA  533507401164427  1039201400023
# 29891   VITAMEDIC INDUSTRIA FARMACEUTICA LTDA  533507402160425  1039201400031
# 29892              PRATI DONADUZZI & CIA LTDA  528526201160419  1256801730019
# 29893                 NATULAB LABORATÓRIO S.A  540420050013307  1384100600048
#
# 41             EAN 1          EAN 2       EAN 3       PRODUTO  \
# 42     7891106000956         -           -         BAYCUTEN N
# 43     7896016806469         -           -            ORENCIA
# 44     7896016807442         -           -            ORENCIA
# 45     7896016808197         -           -            ORENCIA
# 46     7896212452453         -           -             REOPRO
# ...              ...            ...         ...           ...
# 29889  7891317469610  7891317020118      -        SIMECO PLUS
# 29890  7898049793914         -           -           VITAGLÓS
# 29891  7898049791309         -           -           VITAGLÓS
# 29892  7898148295500         -           -          PRATIGLÓS
# 29893  7899470800325         -           -       VITER C + ZN
#
# 41                                          APRESENTAÇÃO  ...   PMC 22%  \
# 42        10 MG/G + 0,443 MG/G CREM DERM CT BG AL X 40 G  ...     50.99
# 43      250 MG PO LIOF SOL INJ CT 1 FA + SER DESCARTÁVEL  ...       NaN
# 44                125 MG/ML SOL INJ SC CT SER PREENCHIDA  ...   2845.30
# 45     125 MG/ML SOL INJ SC CT 4 SER PREENC VD TRANS ...  ...  11381.34
# 46                   2 MG/ML SOL INJ CT FA VD INC X 5 ML  ...       NaN
# ...                                                  ...  ...       ...
# 29889  120 MG/ML + 60 MG/ML + 7 MG/ML SUS OR CT FR VD...  ...     16.09
# 29890    5500UI/G + 990UI/G + 150MG/G POM CT BG AL X 45G  ...     26.78
# 29891  5500UI/G + 990UI/G + 150MG/G POM CX 50 BG AL X...  ...   1028.28
# 29892  5000 UI/G + 900 UI/G + 150 MG/G POM CX 50 BG A...  ...       NaN
# 29893              1 G + 10 MG COM EFERV CT TB PLAS X 10  ...     39.36
#
# 41    PMC 22% ALC RESTRIÇÃO HOSPITALAR  CAP CONFAZ 87 ICMS 0%  \
# 42          45.70                  Não  Não       Não     Não
# 43            NaN                  Sim  Sim       Não     Não
# 44        2845.30                  Não  Sim       Não     Não
# 45       11381.34                  Não  Sim       Sim     Não
# 46            NaN                  Sim  Não       Não     Não
# ...           ...                  ...  ...       ...     ...
# 29889       14.42                  Não  Não       Não     Não
# 29890       24.00                  Não  Não       Não     Não
# 29891      921.60                  Não  Não       Não     Não
# 29892         NaN                  Sim  Não       Não     Não
# 29893       35.28                  Não  Não       Não     Não
#
# 41    ANÁLISE RECURSAL LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/COFINS)  \
# 42                 NaN                                           Negativa
# 43                 NaN                                           Positiva
# 44                 NaN                                           Positiva
# 45                 NaN                                           Positiva
# 46                 NaN                                           Positiva
# ...                ...                                                ...
# 29889              NaN                                           Negativa
# 29890              NaN                                           Negativa
# 29891              NaN                                           Negativa
# 29892              NaN                                           Negativa
# 29893              NaN                                           Negativa
#
# 41    COMERCIALIZAÇÃO 2022            TARJA
# 42                     Sim           - (*)
# 43                     Sim   Tarja Vermelha
# 44                     Não           - (*)
# 45                     Sim           - (*)
# 46                     Não           - (*)
# ...                    ...              ...
# 29889                  Não  Tarja Sem Tarja
# 29890                  Não           - (*)
# 29891                  Não           - (*)
# 29892                  Não           - (*)
# 29893                  Não           - (*)
#
# [29852 rows x 63 columns]

# %%
conn_string = 'postgresql://postgres:postgres@192.168.56.101:5432/postgres'

engine = create_engine(conn_string)
conn = engine.connect() 
conn

# %%
df.to_sql('conformitysite', con=conn, if_exists='replace', schema='imp', index=False)
# Out:
# 852

# %%
conn = psycopg2.connect(conn_string)

# %%
conn.autocommit = True
cursor = conn.cursor() 
conn.commit()
conn.close()
